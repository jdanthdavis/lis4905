# %%
#!/usr/bin/env python3
import pandas as pdr
import matplotlib.pyplot as plt

# %%
def get_requirements():
    print("Data Manipulation")
    print("\nProgram Requirements:")
    print("1. Data Cleaning and Manipulation.")
    print("2. Import necessary libraries.")
    print("3. Research how to install any missing packages, if necessary.")
    print("4. Create at least three functions that are called by the program.")
    print("\ta. main(): calls at least two other functions.")
    print("\tb. get_requirements(): displays the programs requirements.")
    print("\tc. data_manipulation(): displays the programs requirements.")
    print("5. Use imbd-movie-data.csv dataset.")
    print("6. When running program:")
    print("\ta. Document any issues.")
    print("\tb. Document solutions attempted.")
    print("\n***DataFram composed of three components: index, columns, and data. Data also known as values***")

# %%
def data_manipulation():
    my_path = r"C:\Users\Alex\lis4905_sum21\projects\ab16m\week8\imdb-movie-data.csv"
    df = pdr.read_csv(my_path)

    print("\n1. Print indexes:")
    print(df.index)

    print("\n2. Print columns: (Due to confidentiality, only attributes/features 'Time,' 'Amount,' and 'Class' available.")
    print(df.columns)

    print("\n3. Print data frame:")
    print(df)

    print("\n4. Print type:")
    print(type(df))

    print("\n5. Print attribute data types--object type represents strings:")
    print(df.dtypes)

    print("\n6. Print values (truncated list) in array format:")
    print(df.values)

    print("\n7. Print first 5 records, in non-array format:")
    print(df.head())

    print("\n8. Print index of all DataFrame columns names:")
    print(df.columns)

    print("\n9. Print DataFrame info (i.e., summary, similar to 'describe tablename;' in MySQL):")
    print(df.info())

    print("\n10. Print *only* number of DataFrame rows:")
    print(len(df))

    print("\n11. Print *only* number of DataFrame columns:")
    print(len(df.columns))

    print("\n12. Print number of DataFrame rows and columns:")
    print(df.shape)

    print("\n13. Print number of DataFrame elements (i.e., rows * columns):")
    print(df.size)

    print("\n14. Series: one-dimensional labeled array, can hold disparate date types")
    print("(e.g., integer, string, float, Boolean, Python objects, etc.):")
    my_list = [1, "Hello World", 3.5, True, 6, {"banana", "cherry", "apple"}]
    my_series = pdr.Series(my_list)
    print(my_series)

    print("\n15. DataFrame: multi-dimensional table, essentially, two Series.")
    print("Note: Various ways to create DataFrame.")
    print("Here, create dictionary (key:value pairs), ordered (since 3.7), mutable, and doesnot allow duplicates.")
    print("Then, pass it to pandas DataFrame constructor (Note: indexes automatically provided.):")
    vegetable = [3, 2, 0, 1, 5, 4, 7, 6]
    fruit = [0, 3, 7, 2, 1, 6, 4, 5]
    stuff = {"vegetables" : vegetable,
             "fruits" : fruit}
    names = ["Bob", "Jane", "Joe", "Peter", "Viola", "Thomas", "Raquel", "Nicole"]
    td_dataframe = pdr.DataFrame(data=stuff)
    print(td_dataframe)
    print("\nThen, add customer names as indexes:\n")
    td_dataframe2 = pdr.DataFrame(data=stuff, index=names)
    print(td_dataframe2)

    print("\nLocate customer's order by name:")
    print(td_dataframe2.loc["Jane"])

    print("\n17. Convert DataFrame to following file type: .csv and .json (save to same directory):")
    td_dataframe2.to_csv(path_or_buf=r"C:\Users\Alex\lis4905_sum21\projects\ab16m\week8\file.csv")
    td_dataframe2.to_json(path_or_buf=r"C:\Users\Alex\lis4905_sum21\projects\ab16m\week8\jfile.json")

    print("\n18. Create DataFrame for imdb-movie-data.csv, designate movie ***titles*** as index, and print 1st five records:")

    df.index = df["Title"]
    print(df)

    print("\n19. Display last three records:")
    print(df.tail(3))

    print("\n20. Handling duplicates using append(). (Note: Twice as many rows.):")
    df = df.append(df)
    print(df.shape)

    print("\n21. Cleaning duplicates using drop_duplicates():")
    df = df.drop_duplicates()
    print(df.shape)

    print("\n22. Cleaning column names using rename(), and list comprehension.")
    print("Original column names:")
    #df = pdr.read_csv(my_path)
    print(df.columns)
    print("\n22a. Remove parentheses using rename():")
    df = df.rename(columns={'Revenue (Millions)':"revenue_millions"})
    print(df.columns)
    print("\n22b. Make column names lower case, manually using list assignment")
    columns=['rank','title', 'genre', 'description', 'director', 'actors', 'year', 'runtime', 'rating', 'votes', 'revenue_millions', 'metascore']
    df.columns = columns
    print(df.columns)
    print("\n22c. Make column names lower case using list comprehension and lower():")
    df.columns = [i.lower() for i in df.columns]
    print(df.columns)
    print("23. Working with missing (null) values: 1) remove, or 2) replace (imputation).")
    print("\n\tStep 1: Identify null cells:")
    print(df.isna())
    print("\n\tStep2: Count number of nulls in each column:")
    print(df.isna().sum())
    print("\n\t23a. NB: Remove nulls, *only* with small amount of missing data (<5%): \n Note: dropna() removes rows w/at least one null value, \n and returns new DataFrame, w/o affecting original. \n axis=0 (rows default), axis = 1 columns \n Where does \'axis\' come from? Remember: df.shape returns rows(0)/cols(1).")
    print(df.dropna(axis=0))
    print("\t23b. Remove nulls (columns):")
    print(df.dropna(axis=1))
    print("\t23c. Imputation: Replace missing values with guessed/estimated value. \n Use data and relationships among non-missing predictors to estimate missing values.\n One (simple) way: Apply central tendency values (i.e., mean, median, mode).")
    print("\n\tStep 1: Extract column with null values into variable, and print 1st 5 records: \n Note: \"Title\" index remains.")
    print(df["revenue_millions"].head())
    print("\n\tStep 2: Return mean value:")
    print(df["revenue_millions"].mean())
    print("\n\tStep 3: Impute mean value using fillna() and inplace=True, then print nulls. \n Remember: inplace=True affects original DataFrame.")
    df["revenue_millions"].fillna(df["revenue_millions"].mean(),inplace=True)
    print(df.isna().sum())
    print("\n24. Basic statistical analyses using describe(), summary of *continuous* variables. \n Understanding data values (e.g., continuous vs. categorical) assists when determining plot types.")
    print(df.describe())
    print("\n25. Basic statistical analyses using describe(), summary of *categorical* variable (here, only *one* attribute). \n Returns row count, unique count of categories, top category, and freq of top categor(y/ies).")
    print(df['genre'].describe())
    print("\n26. Frequency of all (values_counts()) in a column (here, 'genre') returns 1st 10:")
    dataseries = df['genre'].squeeze()
    print(dataseries.value_counts().head(10))
    print("\n27. Relationships between variables using .corr() method:")
    print(df.corr())
    print("\n28. Conditional selections.")
    print("\n\t28a. Display oldest and newest release years for movies is dataset:")
    max_y = df["year"].max()
    min_y = df["year"].min()
    print(f"Oldest: {max_y}, Newest: {min_y}")
    
    print("\n\t28b. Filter by one director, return 3 records:")
    print(df[df['director']=="Clint Eastwood"].head(3))
    print("\n\t28c. Filter by rating (>=8.0), return 3 records:")
    print(df[df['rating']>=8.0].head(3))
    print("\n\t28d. Filter by two directors (using 'or'). Logical operators | for 'or' & for 'and', return 1st 5 records:")
    print(df[(df['director']=="James Gunn") | (df['director']=="Clint Eastwood")].head(5))
    print("\n\t28e. Filter by same two directories (using 'isin'), return 1st 5 records:")
    directors = ["Clint Eastwood", "James Gunn"]
    print(df[df['director'].isin(directors)].head(5))
    print("\n\t28f. Filter by all movies released between 2005 and 2010, inclusive, having rating above 8.5:")
    print(df[(df['year'] >= 2005) & (df['year'] <= 2010) & (df['rating'] > 8.5)])
    print("\n\t28g. Filter by all movies released between 2005 and 2010, inclusive, having rating above 8.0, and made above or equal to 25th percentile in revenue:")
    q75 = df['revenue_millions'].quantile(0.75)
    print(df[(df['year'] >= 2005) & (df['year'] <= 2010) & (df['rating'] > 8.0) & (df['revenue_millions'] > q75) ])
    print("\n29. Crate function, watch_rating(), return 'yes' or 'no' based upon 8.5 or greater rating. \nUse Python's apply() function to pass 'rating' attribute to function,\nand assign return values to new attribute 'watch_movie', display 1st 10 rows.")
    def watch_rating(rating):
        if rating > 8.5:
            return "Yes"
        else:
            return "False"

    df['watch_rating'] = df['rating'].apply(func=watch_rating)
    print(df.head(10))

# %%
def main():
    get_requirements()
    data_manipulation()

# %%
if __name__ == "__main__":
    main()
# Out:
# Data Manipulation
#
# Program Requirements:
# 1. Data Cleaning and Manipulation.
# 2. Import necessary libraries.
# 3. Research how to install any missing packages, if necessary.
# 4. Create at least three functions that are called by the program.
# 	a. main(): calls at least two other functions.
# 	b. get_requirements(): displays the programs requirements.
# 	c. data_manipulation(): displays the programs requirements.
# 5. Use imbd-movie-data.csv dataset.
# 6. When running program:
# 	a. Document any issues.
# 	b. Document solutions attempted.
#
# ***DataFram composed of three components: index, columns, and data. Data also known as values***
#
# 1. Print indexes:
# RangeIndex(start=0, stop=1000, step=1)
#
# 2. Print columns: (Due to confidentiality, only attributes/features 'Time,' 'Amount,' and 'Class' available.
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
#
# 3. Print data frame:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 995  A tight-knit team of rising investigators, alo...             Billy Ray
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...        Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# ..                                                 ...   ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 1                  124     7.0  485820              126.46       65.0
# 2                  117     7.3  157606              138.12       62.0
# 3                  108     7.2   60545              270.32       59.0
# 4                  123     6.2  393727              325.02       40.0
# ..                 ...     ...     ...                 ...        ...
# 995                111     6.2   27585                 NaN       45.0
# 996                 94     5.5   73152               17.54       46.0
# 997                 98     6.2   70699               58.01       50.0
# 998                 93     5.6    4881                 NaN       22.0
# 999                 87     5.3   12435               19.64       11.0
#
# [1000 rows x 12 columns]
#
# 4. Print type:
# <class 'pandas.core.frame.DataFrame'>
#
# 5. Print attribute data types--object type represents strings:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object
#
# 6. Print values (truncated list) in array format:
# [[1 'Guardians of the Galaxy' 'Action,Adventure,Sci-Fi' ... 757074 333.13
#   76.0]
#  [2 'Prometheus' 'Adventure,Mystery,Sci-Fi' ... 485820 126.46 65.0]
#  [3 'Split' 'Horror,Thriller' ... 157606 138.12 62.0]
#  ...
#  [998 'Step Up 2: The Streets' 'Drama,Music,Romance' ... 70699 58.01 50.0]
#  [999 'Search Party' 'Adventure,Comedy' ... 4881 nan 22.0]
#  [1000 'Nine Lives' 'Comedy,Family,Fantasy' ... 12435 19.64 11.0]]
#
# 7. Print first 5 records, in non-array format:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0
#
# 8. Print index of all DataFrame columns names:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
#
# 9. Print DataFrame info (i.e., summary, similar to 'describe tablename;' in MySQL):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB
# None
#
# 10. Print *only* number of DataFrame rows:
# 1000
#
# 11. Print *only* number of DataFrame columns:
# 12
#
# 12. Print number of DataFrame rows and columns:
# (1000, 12)
#
# 13. Print number of DataFrame elements (i.e., rows * columns):
# 12000
#
# 14. Series: one-dimensional labeled array, can hold disparate date types
# (e.g., integer, string, float, Boolean, Python objects, etc.):
# 0                          1
# 1                Hello World
# 2                        3.5
# 3                       True
# 4                          6
# 5    {banana, apple, cherry}
# dtype: object
#
# 15. DataFrame: multi-dimensional table, essentially, two Series.
# Note: Various ways to create DataFrame.
# Here, create dictionary (key:value pairs), ordered (since 3.7), mutable, and doesnot allow duplicates.
# Then, pass it to pandas DataFrame constructor (Note: indexes automatically provided.):
#    vegetables  fruits
# 0           3       0
# 1           2       3
# 2           0       7
# 3           1       2
# 4           5       1
# 5           4       6
# 6           7       4
# 7           6       5
#
# Then, add customer names as indexes:
#
#         vegetables  fruits
# Bob              3       0
# Jane             2       3
# Joe              0       7
# Peter            1       2
# Viola            5       1
# Thomas           4       6
# Raquel           7       4
# Nicole           6       5
#
# Locate customer's order by name:
# vegetables    2
# fruits        3
# Name: Jane, dtype: int64
#
# 17. Convert DataFrame to following file type: .csv and .json (save to same directory):
#
# 18. Create DataFrame for imdb-movie-data.csv, designate movie ***titles*** as index, and print 1st five records:
#                          Rank                    Title  \
# Title
# Guardians of the Galaxy     1  Guardians of the Galaxy
# Prometheus                  2               Prometheus
# Split                       3                    Split
# Sing                        4                     Sing
# Suicide Squad               5            Suicide Squad
# ...                       ...                      ...
# Secret in Their Eyes      996     Secret in Their Eyes
# Hostel: Part II           997          Hostel: Part II
# Step Up 2: The Streets    998   Step Up 2: The Streets
# Search Party              999             Search Party
# Nine Lives               1000               Nine Lives
#
#                                             Genre  \
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# ...                                                                    ...
# Secret in Their Eyes     A tight-knit team of rising investigators, alo...
# Hostel: Part II          Three American college students studying abroa...
# Step Up 2: The Streets   Romantic sparks occur between two dance studen...
# Search Party             A pair of friends embark on a mission to reuni...
# Nine Lives               A stuffy businessman finds himself trapped ins...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# ...                                       ...
# Secret in Their Eyes                Billy Ray
# Hostel: Part II                      Eli Roth
# Step Up 2: The Streets             Jon M. Chu
# Search Party                   Scot Armstrong
# Nine Lives                   Barry Sonnenfeld
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# ...                                                                    ...
# Secret in Their Eyes     Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# Hostel: Part II          Lauren German, Heather Matarazzo, Bijou Philli...
# Step Up 2: The Streets   Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party             Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Nine Lives               Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
# Split                    2016                117     7.3  157606
# Sing                     2016                108     7.2   60545
# Suicide Squad            2016                123     6.2  393727
# ...                       ...                ...     ...     ...
# Secret in Their Eyes     2015                111     6.2   27585
# Hostel: Part II          2007                 94     5.5   73152
# Step Up 2: The Streets   2008                 98     6.2   70699
# Search Party             2014                 93     5.6    4881
# Nine Lives               2016                 87     5.3   12435
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0
# Split                                138.12       62.0
# Sing                                 270.32       59.0
# Suicide Squad                        325.02       40.0
# ...                                     ...        ...
# Secret in Their Eyes                    NaN       45.0
# Hostel: Part II                       17.54       46.0
# Step Up 2: The Streets                58.01       50.0
# Search Party                            NaN       22.0
# Nine Lives                            19.64       11.0
#
# [1000 rows x 12 columns]
#
# 19. Display last three records:
#                         Rank                   Title                  Genre  \
# Title
# Step Up 2: The Streets   998  Step Up 2: The Streets    Drama,Music,Romance
# Search Party             999            Search Party       Adventure,Comedy
# Nine Lives              1000              Nine Lives  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Step Up 2: The Streets        Jon M. Chu
# Search Party              Scot Armstrong
# Nine Lives              Barry Sonnenfeld
#
#                                                                    Actors  \
# Title
# Step Up 2: The Streets  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party            Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Nine Lives              Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                         Year  Runtime (Minutes)  Rating  Votes  \
# Title
# Step Up 2: The Streets  2008                 98     6.2  70699
# Search Party            2014                 93     5.6   4881
# Nine Lives              2016                 87     5.3  12435
#
#                         Revenue (Millions)  Metascore
# Title
# Step Up 2: The Streets               58.01       50.0
# Search Party                           NaN       22.0
# Nine Lives                           19.64       11.0
#
# 20. Handling duplicates using append(). (Note: Twice as many rows.):
# (2000, 12)
#
# 21. Cleaning duplicates using drop_duplicates():
# (1000, 12)
#
# 22. Cleaning column names using rename(), and list comprehension.
# Original column names:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
#
# 22a. Remove parentheses using rename():
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'revenue_millions',
#        'Metascore'],
#       dtype='object')
#
# 22b. Make column names lower case, manually using list assignment
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')
#
# 22c. Make column names lower case using list comprehension and lower():
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')
# 23. Working with missing (null) values: 1) remove, or 2) replace (imputation).
#
# 	Step 1: Identify null cells:
#                           rank  title  genre  description  director  actors  \
# Title
# Guardians of the Galaxy  False  False  False        False     False   False
# Prometheus               False  False  False        False     False   False
# Split                    False  False  False        False     False   False
# Sing                     False  False  False        False     False   False
# Suicide Squad            False  False  False        False     False   False
# ...                        ...    ...    ...          ...       ...     ...
# Secret in Their Eyes     False  False  False        False     False   False
# Hostel: Part II          False  False  False        False     False   False
# Step Up 2: The Streets   False  False  False        False     False   False
# Search Party             False  False  False        False     False   False
# Nine Lives               False  False  False        False     False   False
#
#                           year  runtime  rating  votes  revenue_millions  \
# Title
# Guardians of the Galaxy  False    False   False  False             False
# Prometheus               False    False   False  False             False
# Split                    False    False   False  False             False
# Sing                     False    False   False  False             False
# Suicide Squad            False    False   False  False             False
# ...                        ...      ...     ...    ...               ...
# Secret in Their Eyes     False    False   False  False              True
# Hostel: Part II          False    False   False  False             False
# Step Up 2: The Streets   False    False   False  False             False
# Search Party             False    False   False  False              True
# Nine Lives               False    False   False  False             False
#
#                          metascore
# Title
# Guardians of the Galaxy      False
# Prometheus                   False
# Split                        False
# Sing                         False
# Suicide Squad                False
# ...                            ...
# Secret in Their Eyes         False
# Hostel: Part II              False
# Step Up 2: The Streets       False
# Search Party                 False
# Nine Lives                   False
#
# [1000 rows x 12 columns]
#
# 	Step2: Count number of nulls in each column:
# rank                  0
# title                 0
# genre                 0
# description           0
# director              0
# actors                0
# year                  0
# runtime               0
# rating                0
# votes                 0
# revenue_millions    128
# metascore            64
# dtype: int64
#
# 	23a. NB: Remove nulls, *only* with small amount of missing data (<5%):
#  Note: dropna() removes rows w/at least one null value,
#  and returns new DataFrame, w/o affecting original.
#  axis=0 (rows default), axis = 1 columns
#  Where does 'axis' come from? Remember: df.shape returns rows(0)/cols(1).
#                           rank                     title  \
# Title
# Guardians of the Galaxy      1   Guardians of the Galaxy
# Prometheus                   2                Prometheus
# Split                        3                     Split
# Sing                         4                      Sing
# Suicide Squad                5             Suicide Squad
# ...                        ...                       ...
# Resident Evil: Afterlife   994  Resident Evil: Afterlife
# Project X                  995                 Project X
# Hostel: Part II            997           Hostel: Part II
# Step Up 2: The Streets     998    Step Up 2: The Streets
# Nine Lives                1000                Nine Lives
#
#                                              genre  \
# Title
# Guardians of the Galaxy    Action,Adventure,Sci-Fi
# Prometheus                Adventure,Mystery,Sci-Fi
# Split                              Horror,Thriller
# Sing                       Animation,Comedy,Family
# Suicide Squad             Action,Adventure,Fantasy
# ...                                            ...
# Resident Evil: Afterlife   Action,Adventure,Horror
# Project X                                   Comedy
# Hostel: Part II                             Horror
# Step Up 2: The Streets         Drama,Music,Romance
# Nine Lives                   Comedy,Family,Fantasy
#
#                                                                 description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# Split                     Three girls are kidnapped by a man with a diag...
# Sing                      In a city of humanoid animals, a hustling thea...
# Suicide Squad             A secret government agency recruits some of th...
# ...                                                                     ...
# Resident Evil: Afterlife  While still out to destroy the evil Umbrella C...
# Project X                 3 high school seniors throw a birthday party t...
# Hostel: Part II           Three American college students studying abroa...
# Step Up 2: The Streets    Romantic sparks occur between two dance studen...
# Nine Lives                A stuffy businessman finds himself trapped ins...
#
#                                       director  \
# Title
# Guardians of the Galaxy             James Gunn
# Prometheus                        Ridley Scott
# Split                       M. Night Shyamalan
# Sing                      Christophe Lourdelet
# Suicide Squad                       David Ayer
# ...                                        ...
# Resident Evil: Afterlife    Paul W.S. Anderson
# Project X                      Nima Nourizadeh
# Hostel: Part II                       Eli Roth
# Step Up 2: The Streets              Jon M. Chu
# Nine Lives                    Barry Sonnenfeld
#
#                                                                      actors  \
# Title
# Guardians of the Galaxy   Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus                Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                     James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                      Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad             Will Smith, Jared Leto, Margot Robbie, Viola D...
# ...                                                                     ...
# Resident Evil: Afterlife  Milla Jovovich, Ali Larter, Wentworth Miller,K...
# Project X                 Thomas Mann, Oliver Cooper, Jonathan Daniel Br...
# Hostel: Part II           Lauren German, Heather Matarazzo, Bijou Philli...
# Step Up 2: The Streets    Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Nine Lives                Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                           year  runtime  rating   votes  revenue_millions  \
# Title
# Guardians of the Galaxy   2014      121     8.1  757074            333.13
# Prometheus                2012      124     7.0  485820            126.46
# Split                     2016      117     7.3  157606            138.12
# Sing                      2016      108     7.2   60545            270.32
# Suicide Squad             2016      123     6.2  393727            325.02
# ...                        ...      ...     ...     ...               ...
# Resident Evil: Afterlife  2010       97     5.9  140900             60.13
# Project X                 2012       88     6.7  164088             54.72
# Hostel: Part II           2007       94     5.5   73152             17.54
# Step Up 2: The Streets    2008       98     6.2   70699             58.01
# Nine Lives                2016       87     5.3   12435             19.64
#
#                           metascore
# Title
# Guardians of the Galaxy        76.0
# Prometheus                     65.0
# Split                          62.0
# Sing                           59.0
# Suicide Squad                  40.0
# ...                             ...
# Resident Evil: Afterlife       37.0
# Project X                      48.0
# Hostel: Part II                46.0
# Step Up 2: The Streets         50.0
# Nine Lives                     11.0
#
# [838 rows x 12 columns]
# 	23b. Remove nulls (columns):
#                          rank                    title  \
# Title
# Guardians of the Galaxy     1  Guardians of the Galaxy
# Prometheus                  2               Prometheus
# Split                       3                    Split
# Sing                        4                     Sing
# Suicide Squad               5            Suicide Squad
# ...                       ...                      ...
# Secret in Their Eyes      996     Secret in Their Eyes
# Hostel: Part II           997          Hostel: Part II
# Step Up 2: The Streets    998   Step Up 2: The Streets
# Search Party              999             Search Party
# Nine Lives               1000               Nine Lives
#
#                                             genre  \
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# ...                                                                    ...
# Secret in Their Eyes     A tight-knit team of rising investigators, alo...
# Hostel: Part II          Three American college students studying abroa...
# Step Up 2: The Streets   Romantic sparks occur between two dance studen...
# Search Party             A pair of friends embark on a mission to reuni...
# Nine Lives               A stuffy businessman finds himself trapped ins...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# ...                                       ...
# Secret in Their Eyes                Billy Ray
# Hostel: Part II                      Eli Roth
# Step Up 2: The Streets             Jon M. Chu
# Search Party                   Scot Armstrong
# Nine Lives                   Barry Sonnenfeld
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# ...                                                                    ...
# Secret in Their Eyes     Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# Hostel: Part II          Lauren German, Heather Matarazzo, Bijou Philli...
# Step Up 2: The Streets   Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party             Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Nine Lives               Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                          year  runtime  rating   votes
# Title
# Guardians of the Galaxy  2014      121     8.1  757074
# Prometheus               2012      124     7.0  485820
# Split                    2016      117     7.3  157606
# Sing                     2016      108     7.2   60545
# Suicide Squad            2016      123     6.2  393727
# ...                       ...      ...     ...     ...
# Secret in Their Eyes     2015      111     6.2   27585
# Hostel: Part II          2007       94     5.5   73152
# Step Up 2: The Streets   2008       98     6.2   70699
# Search Party             2014       93     5.6    4881
# Nine Lives               2016       87     5.3   12435
#
# [1000 rows x 10 columns]
# 	23c. Imputation: Replace missing values with guessed/estimated value.
#  Use data and relationships among non-missing predictors to estimate missing values.
#  One (simple) way: Apply central tendency values (i.e., mean, median, mode).
#
# 	Step 1: Extract column with null values into variable, and print 1st 5 records:
#  Note: "Title" index remains.
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
# Name: revenue_millions, dtype: float64
#
# 	Step 2: Return mean value:
# 82.95637614678897
#
# 	Step 3: Impute mean value using fillna() and inplace=True, then print nulls.
#  Remember: inplace=True affects original DataFrame.
# rank                 0
# title                0
# genre                0
# description          0
# director             0
# actors               0
# year                 0
# runtime              0
# rating               0
# votes                0
# revenue_millions     0
# metascore           64
# dtype: int64
#
# 24. Basic statistical analyses using describe(), summary of *continuous* variables.
#  Understanding data values (e.g., continuous vs. categorical) assists when determining plot types.
#               rank         year      runtime       rating         votes  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000   113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962    18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000    66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000   100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000   111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000   123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000   191.000000     9.000000  1.791916e+06
#
#        revenue_millions   metascore
# count       1000.000000  936.000000
# mean          82.956376   58.985043
# std           96.412043   17.194757
# min            0.000000   11.000000
# 25%           17.442500   47.000000
# 50%           60.375000   59.500000
# 75%           99.177500   72.000000
# max          936.630000  100.000000
#
# 25. Basic statistical analyses using describe(), summary of *categorical* variable (here, only *one* attribute).
#  Returns row count, unique count of categories, top category, and freq of top categor(y/ies).
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: genre, dtype: object
#
# 26. Frequency of all (values_counts()) in a column (here, 'genre') returns 1st 10:
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Comedy,Drama                  27
# Action,Adventure,Fantasy      27
# Animation,Adventure,Comedy    27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Name: genre, dtype: int64
#
# 27. Relationships between variables using .corr() method:
#                       rank      year   runtime    rating     votes  \
# rank              1.000000 -0.261605 -0.221739 -0.219555 -0.283876
# year             -0.261605  1.000000 -0.164900 -0.211219 -0.411904
# runtime          -0.221739 -0.164900  1.000000  0.392214  0.407062
# rating           -0.219555 -0.211219  0.392214  1.000000  0.511537
# votes            -0.283876 -0.411904  0.407062  0.511537  1.000000
# revenue_millions -0.252996 -0.117562  0.247834  0.189527  0.607941
# metascore        -0.191869 -0.079305  0.211978  0.631897  0.325684
#
#                   revenue_millions  metascore
# rank                     -0.252996  -0.191869
# year                     -0.117562  -0.079305
# runtime                   0.247834   0.211978
# rating                    0.189527   0.631897
# votes                     0.607941   0.325684
# revenue_millions          1.000000   0.133328
# metascore                 0.133328   1.000000
#
# 28. Conditional selections.
#
# 	28a. Display oldest and newest release years for movies is dataset:
# Oldest: 2016, Newest: 2006
#
# 	28b. Filter by one director, return 3 records:
#                  rank            title                   genre  \
# Title
# Sully              60            Sully         Biography,Drama
# American Sniper   332  American Sniper  Action,Biography,Drama
# Gran Torino       646      Gran Torino                   Drama
#
#                                                        description  \
# Title
# Sully            The story of Chesley Sullenberger, an American...
# American Sniper  Navy S.E.A.L. sniper Chris Kyle's pinpoint acc...
# Gran Torino      Disgruntled Korean War veteran Walt Kowalski s...
#
#                        director  \
# Title
# Sully            Clint Eastwood
# American Sniper  Clint Eastwood
# Gran Torino      Clint Eastwood
#
#                                                             actors  year  \
# Title
# Sully            Tom Hanks, Aaron Eckhart, Laura Linney, Valeri...  2016
# American Sniper  Bradley Cooper, Sienna Miller, Kyle Gallner, C...  2014
# Gran Torino      Clint Eastwood, Bee Vang, Christopher Carley,A...  2008
#
#                  runtime  rating   votes  revenue_millions  metascore
# Title
# Sully                 96     7.5  137608            125.07       74.0
# American Sniper      133     7.3  353305            350.12       72.0
# Gran Torino          116     8.2  595779            148.09        NaN
#
# 	28c. Filter by rating (>=8.0), return 3 records:
#                          rank                    title  \
# Title
# Guardians of the Galaxy     1  Guardians of the Galaxy
# La La Land                  7               La La Land
# Hacksaw Ridge              17            Hacksaw Ridge
#
#                                            genre  \
# Title
# Guardians of the Galaxy  Action,Adventure,Sci-Fi
# La La Land                    Comedy,Drama,Music
# Hacksaw Ridge            Biography,Drama,History
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# La La Land               A jazz pianist falls for an aspiring actress i...
# Hacksaw Ridge            WWII American Army Medic Desmond T. Doss, who ...
#
#                                 director  \
# Title
# Guardians of the Galaxy       James Gunn
# La La Land               Damien Chazelle
# Hacksaw Ridge                 Mel Gibson
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# La La Land               Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# Hacksaw Ridge            Andrew Garfield, Sam Worthington, Luke Bracey,...
#
#                          year  runtime  rating   votes  revenue_millions  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074            333.13
# La La Land               2016      128     8.3  258682            151.06
# Hacksaw Ridge            2016      139     8.2  211760             67.12
#
#                          metascore
# Title
# Guardians of the Galaxy       76.0
# La La Land                    93.0
# Hacksaw Ridge                 71.0
#
# 	28d. Filter by two directors (using 'or'). Logical operators | for 'or' & for 'and', return 1st 5 records:
#                          rank                    title  \
# Title
# Guardians of the Galaxy     1  Guardians of the Galaxy
# Sully                      60                    Sully
# American Sniper           332          American Sniper
# Gran Torino               646              Gran Torino
# Changeling                860               Changeling
#
#                                            genre  \
# Title
# Guardians of the Galaxy  Action,Adventure,Sci-Fi
# Sully                            Biography,Drama
# American Sniper           Action,Biography,Drama
# Gran Torino                                Drama
# Changeling               Biography,Drama,Mystery
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Sully                    The story of Chesley Sullenberger, an American...
# American Sniper          Navy S.E.A.L. sniper Chris Kyle's pinpoint acc...
# Gran Torino              Disgruntled Korean War veteran Walt Kowalski s...
# Changeling               A grief-stricken mother takes on the LAPD to h...
#
#                                director  \
# Title
# Guardians of the Galaxy      James Gunn
# Sully                    Clint Eastwood
# American Sniper          Clint Eastwood
# Gran Torino              Clint Eastwood
# Changeling               Clint Eastwood
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Sully                    Tom Hanks, Aaron Eckhart, Laura Linney, Valeri...
# American Sniper          Bradley Cooper, Sienna Miller, Kyle Gallner, C...
# Gran Torino              Clint Eastwood, Bee Vang, Christopher Carley,A...
# Changeling               Angelina Jolie, Colm Feore, Amy Ryan, Gattlin ...
#
#                          year  runtime  rating   votes  revenue_millions  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074            333.13
# Sully                    2016       96     7.5  137608            125.07
# American Sniper          2014      133     7.3  353305            350.12
# Gran Torino              2008      116     8.2  595779            148.09
# Changeling               2008      141     7.8  206793             35.71
#
#                          metascore
# Title
# Guardians of the Galaxy       76.0
# Sully                         74.0
# American Sniper               72.0
# Gran Torino                    NaN
# Changeling                    63.0
#
# 	28e. Filter by same two directories (using 'isin'), return 1st 5 records:
#                          rank                    title  \
# Title
# Guardians of the Galaxy     1  Guardians of the Galaxy
# Sully                      60                    Sully
# American Sniper           332          American Sniper
# Gran Torino               646              Gran Torino
# Changeling                860               Changeling
#
#                                            genre  \
# Title
# Guardians of the Galaxy  Action,Adventure,Sci-Fi
# Sully                            Biography,Drama
# American Sniper           Action,Biography,Drama
# Gran Torino                                Drama
# Changeling               Biography,Drama,Mystery
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Sully                    The story of Chesley Sullenberger, an American...
# American Sniper          Navy S.E.A.L. sniper Chris Kyle's pinpoint acc...
# Gran Torino              Disgruntled Korean War veteran Walt Kowalski s...
# Changeling               A grief-stricken mother takes on the LAPD to h...
#
#                                director  \
# Title
# Guardians of the Galaxy      James Gunn
# Sully                    Clint Eastwood
# American Sniper          Clint Eastwood
# Gran Torino              Clint Eastwood
# Changeling               Clint Eastwood
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Sully                    Tom Hanks, Aaron Eckhart, Laura Linney, Valeri...
# American Sniper          Bradley Cooper, Sienna Miller, Kyle Gallner, C...
# Gran Torino              Clint Eastwood, Bee Vang, Christopher Carley,A...
# Changeling               Angelina Jolie, Colm Feore, Amy Ryan, Gattlin ...
#
#                          year  runtime  rating   votes  revenue_millions  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074            333.13
# Sully                    2016       96     7.5  137608            125.07
# American Sniper          2014      133     7.3  353305            350.12
# Gran Torino              2008      116     8.2  595779            148.09
# Changeling               2008      141     7.8  206793             35.71
#
#                          metascore
# Title
# Guardians of the Galaxy       76.0
# Sully                         74.0
# American Sniper               72.0
# Gran Torino                    NaN
# Changeling                    63.0
#
# 	28f. Filter by all movies released between 2005 and 2010, inclusive, having rating above 8.5:
#                  rank            title                    genre  \
# Title
# The Dark Knight    55  The Dark Knight       Action,Crime,Drama
# Inception          81        Inception  Action,Adventure,Sci-Fi
#
#                                                        description  \
# Title
# The Dark Knight  When the menace known as the Joker wreaks havo...
# Inception        A thief, who steals corporate secrets through ...
#
#                           director  \
# Title
# The Dark Knight  Christopher Nolan
# Inception        Christopher Nolan
#
#                                                             actors  year  \
# Title
# The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# Inception        Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
#
#                  runtime  rating    votes  revenue_millions  metascore
# Title
# The Dark Knight      152     9.0  1791916            533.32       82.0
# Inception            148     8.8  1583625            292.57       74.0
#
# 	28g. Filter by all movies released between 2005 and 2010, inclusive, having rating above 8.0, and made above or equal to 25th percentile in revenue:
#                           rank                     title  \
# Title
# The Dark Knight             55           The Dark Knight
# Inglourious Basterds        78      Inglourious Basterds
# Inception                   81                 Inception
# The Departed               100              The Departed
# Shutter Island             139            Shutter Island
# The Bourne Ultimatum       428      The Bourne Ultimatum
# Up                         500                        Up
# WALL·E                     635                    WALL·E
# Gran Torino                646               Gran Torino
# Toy Story 3                689               Toy Story 3
# How to Train Your Dragon   773  How to Train Your Dragon
#
#                                                genre  \
# Title
# The Dark Knight                   Action,Crime,Drama
# Inglourious Basterds             Adventure,Drama,War
# Inception                    Action,Adventure,Sci-Fi
# The Departed                    Crime,Drama,Thriller
# Shutter Island                      Mystery,Thriller
# The Bourne Ultimatum         Action,Mystery,Thriller
# Up                        Animation,Adventure,Comedy
# WALL·E                    Animation,Adventure,Family
# Gran Torino                                    Drama
# Toy Story 3               Animation,Adventure,Comedy
# How to Train Your Dragon  Animation,Action,Adventure
#
#                                                                 description  \
# Title
# The Dark Knight           When the menace known as the Joker wreaks havo...
# Inglourious Basterds      In Nazi-occupied France during World War II, a...
# Inception                 A thief, who steals corporate secrets through ...
# The Departed              An undercover cop and a mole in the police att...
# Shutter Island            In 1954, a U.S. marshal investigates the disap...
# The Bourne Ultimatum      Jason Bourne dodges a ruthless CIA official an...
# Up                        Seventy-eight year old Carl Fredricksen travel...
# WALL·E                    In the distant future, a small waste-collectin...
# Gran Torino               Disgruntled Korean War veteran Walt Kowalski s...
# Toy Story 3               The toys are mistakenly delivered to a day-car...
# How to Train Your Dragon  A hapless young Viking who aspires to hunt dra...
#
#                                    director  \
# Title
# The Dark Knight           Christopher Nolan
# Inglourious Basterds      Quentin Tarantino
# Inception                 Christopher Nolan
# The Departed                Martin Scorsese
# Shutter Island              Martin Scorsese
# The Bourne Ultimatum        Paul Greengrass
# Up                              Pete Docter
# WALL·E                       Andrew Stanton
# Gran Torino                  Clint Eastwood
# Toy Story 3                     Lee Unkrich
# How to Train Your Dragon       Dean DeBlois
#
#                                                                      actors  \
# Title
# The Dark Knight           Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# Inglourious Basterds      Brad Pitt, Diane Kruger, Eli Roth,Mélanie Laurent
# Inception                 Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# The Departed              Leonardo DiCaprio, Matt Damon, Jack Nicholson,...
# Shutter Island            Leonardo DiCaprio, Emily Mortimer, Mark Ruffal...
# The Bourne Ultimatum      Matt Damon, Edgar Ramírez, Joan Allen, Julia S...
# Up                        Edward Asner, Jordan Nagai, John Ratzenberger,...
# WALL·E                    Ben Burtt, Elissa Knight, Jeff Garlin, Fred Wi...
# Gran Torino               Clint Eastwood, Bee Vang, Christopher Carley,A...
# Toy Story 3                   Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty
# How to Train Your Dragon  Jay Baruchel, Gerard Butler,Christopher Mintz-...
#
#                           year  runtime  rating    votes  revenue_millions  \
# Title
# The Dark Knight           2008      152     9.0  1791916            533.32
# Inglourious Basterds      2009      153     8.3   959065            120.52
# Inception                 2010      148     8.8  1583625            292.57
# The Departed              2006      151     8.5   937414            132.37
# Shutter Island            2010      138     8.1   855604            127.97
# The Bourne Ultimatum      2007      115     8.1   525700            227.14
# Up                        2009       96     8.3   722203            292.98
# WALL·E                    2008       98     8.4   776897            223.81
# Gran Torino               2008      116     8.2   595779            148.09
# Toy Story 3               2010      103     8.3   586669            414.98
# How to Train Your Dragon  2010       98     8.1   523893            217.39
#
#                           metascore
# Title
# The Dark Knight                82.0
# Inglourious Basterds           69.0
# Inception                      74.0
# The Departed                   85.0
# Shutter Island                 63.0
# The Bourne Ultimatum           85.0
# Up                             88.0
# WALL·E                          NaN
# Gran Torino                     NaN
# Toy Story 3                    92.0
# How to Train Your Dragon       74.0
#
# 29. Crate function, watch_rating(), return 'yes' or 'no' based upon 8.5 or greater rating.
# Use Python's apply() function to pass 'rating' attribute to function,
# and assign return values to new attribute 'watch_movie', display 1st 10 rows.
#                          rank                    title  \
# Title
# Guardians of the Galaxy     1  Guardians of the Galaxy
# Prometheus                  2               Prometheus
# Split                       3                    Split
# Sing                        4                     Sing
# Suicide Squad               5            Suicide Squad
# The Great Wall              6           The Great Wall
# La La Land                  7               La La Land
# Mindhorn                    8                 Mindhorn
# The Lost City of Z          9       The Lost City of Z
# Passengers                 10               Passengers
#
#                                               genre  \
# Title
# Guardians of the Galaxy     Action,Adventure,Sci-Fi
# Prometheus                 Adventure,Mystery,Sci-Fi
# Split                               Horror,Thriller
# Sing                        Animation,Comedy,Family
# Suicide Squad              Action,Adventure,Fantasy
# The Great Wall             Action,Adventure,Fantasy
# La La Land                       Comedy,Drama,Music
# Mindhorn                                     Comedy
# The Lost City of Z       Action,Adventure,Biography
# Passengers                  Adventure,Drama,Romance
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# The Great Wall           European mercenaries searching for black powde...
# La La Land               A jazz pianist falls for an aspiring actress i...
# Mindhorn                 A has-been actor best known for playing the ti...
# The Lost City of Z       A true-life drama, centering on British explor...
# Passengers               A spacecraft traveling to a distant colony pla...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# The Great Wall                    Yimou Zhang
# La La Land                    Damien Chazelle
# Mindhorn                           Sean Foley
# The Lost City of Z                 James Gray
# Passengers                      Morten Tyldum
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# The Great Wall               Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# La La Land               Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# Mindhorn                 Essie Davis, Andrea Riseborough, Julian Barrat...
# The Lost City of Z       Charlie Hunnam, Robert Pattinson, Sienna Mille...
# Passengers               Jennifer Lawrence, Chris Pratt, Michael Sheen,...
#
#                          year  runtime  rating   votes  revenue_millions  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074        333.130000
# Prometheus               2012      124     7.0  485820        126.460000
# Split                    2016      117     7.3  157606        138.120000
# Sing                     2016      108     7.2   60545        270.320000
# Suicide Squad            2016      123     6.2  393727        325.020000
# The Great Wall           2016      103     6.1   56036         45.130000
# La La Land               2016      128     8.3  258682        151.060000
# Mindhorn                 2016       89     6.4    2490         82.956376
# The Lost City of Z       2016      141     7.1    7188          8.010000
# Passengers               2016      116     7.0  192177        100.010000
#
#                          metascore watch_rating
# Title
# Guardians of the Galaxy       76.0        False
# Prometheus                    65.0        False
# Split                         62.0        False
# Sing                          59.0        False
# Suicide Squad                 40.0        False
# The Great Wall                42.0        False
# La La Land                    93.0        False
# Mindhorn                      71.0        False
# The Lost City of Z            78.0        False
# Passengers                    41.0        False
