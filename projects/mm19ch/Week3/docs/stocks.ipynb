# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
start = datetime.datetime(2010, 1, 1)
end   = datetime.datetime(2021, 5, 30)

# %%
aapl = web.DataReader("aapl", 'yahoo', start, end)
msft = web.DataReader("msft", 'yahoo', start, end)
googl = web.DataReader("googl", 'yahoo', start, end)

# %%
aapl
msft
googl
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2010-01-04   315.070068   312.432434   313.788788   313.688690   3908488.0
# 2010-01-05   314.234222   311.081085   313.903900   312.307312   6003391.0
# 2010-01-06   313.243256   303.483490   313.243256   304.434448   7949443.0
# 2010-01-07   305.305298   296.621613   305.005005   297.347351  12815771.0
# 2010-01-08   301.926941   294.849854   296.296295   301.311310   9439151.0
# ...                 ...          ...          ...          ...         ...
# 2021-05-24  2365.550049  2311.959961  2314.889893  2361.040039   1591600.0
# 2021-05-25  2384.000000  2355.000000  2372.000000  2362.870117   1122000.0
# 2021-05-26  2388.989990  2366.459961  2366.520020  2380.310059   1078600.0
# 2021-05-27  2389.050049  2356.260010  2389.050049  2362.679932   1761200.0
# 2021-05-28  2376.070068  2352.850098  2374.419922  2356.850098   1074100.0
#
#               Adj Close
# Date
# 2010-01-04   313.688690
# 2010-01-05   312.307312
# 2010-01-06   304.434448
# 2010-01-07   297.347351
# 2010-01-08   301.311310
# ...                 ...
# 2021-05-24  2361.040039
# 2021-05-25  2362.870117
# 2021-05-26  2380.310059
# 2021-05-27  2362.679932
# 2021-05-28  2356.850098
#
# [2871 rows x 6 columns]

# %%
msft['Open'].plot()
plt.show()

aapl['Open'].plot()
plt.show()

googl['Open'].plot()
plt.show()

# %%
aapl['Open'].plot(label = 'AAPL Open price', figsize=(15,5))
msft['Open'].plot(label = 'MSFT Open price')
googl['Open'].plot(label = 'GOOGL Open price')
plt.legend()
plt.title('Comparison')
plt.show()
