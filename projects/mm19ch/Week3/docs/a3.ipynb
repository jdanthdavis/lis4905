# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt

# %%
start = datetime.datetime(2010, 1, 1)
end   = datetime.datetime(2021, 5, 30)

# %%
aapl = web.DataReader("aapl", 'yahoo', start, end)
msft = web.DataReader("msft", 'yahoo', start, end)
googl = web.DataReader("googl", 'yahoo', start, end)

# %%
n = len(aapl)
print(f"\nPrint number of records\n{n}")
print("\nPrint columns: \n")
print(aapl.columns)
print("\n8 Rows:\n")
print(msft.head(8))
print("\nLast 6 rows")
print(msft.tail(6))
# Out:
# Print number of records
# 2871
#
# Print columns:
#
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')
#
# 8 Rows:
#
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2010-01-04  31.100000  30.590000  30.620001  30.950001  38409100.0  23.994564
# 2010-01-05  31.100000  30.639999  30.850000  30.959999  49749600.0  24.002319
# 2010-01-06  31.080000  30.520000  30.879999  30.770000  58182400.0  23.855013
# 2010-01-07  30.700001  30.190001  30.629999  30.450001  50559700.0  23.606922
# 2010-01-08  30.879999  30.240000  30.280001  30.660000  51197400.0  23.769743
# 2010-01-11  30.760000  30.120001  30.709999  30.270000  68754700.0  23.467388
# 2010-01-12  30.400000  29.910000  30.150000  30.070000  65912100.0  23.312330
# 2010-01-13  30.520000  30.010000  30.260000  30.350000  51863500.0  23.529409
#
# Last 6 rows
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-05-21  248.330002  244.740005  247.570007  245.169998  21863100.0
# 2021-05-24  251.160004  247.509995  247.789993  250.779999  21411500.0
# 2021-05-25  252.750000  250.820007  251.770004  251.720001  17704300.0
# 2021-05-26  252.940002  250.750000  251.429993  251.490005  17771600.0
# 2021-05-27  251.479996  249.250000  251.169998  249.309998  24426200.0
# 2021-05-28  252.080002  249.559998  251.000000  249.679993  18270200.0
#
#              Adj Close
# Date
# 2021-05-21  245.169998
# 2021-05-24  250.779999
# 2021-05-25  251.720001
# 2021-05-26  251.490005
# 2021-05-27  249.309998
# 2021-05-28  249.679993

# %%
plt.style.use('dark_background')
msft['Open'].plot()
plt.show()
plt.style.use('ggplot')
aapl['Open'].plot()
plt.show()
plt.style.use('seaborn')
googl['Open'].plot()
plt.show()

# %%
aapl['Open'].plot(label = 'AAPL Open price', figsize=(15,5))
msft['Open'].plot(label = 'MSFT Open price')
googl['Open'].plot(label = 'GOOGL Open price')
plt.legend()
plt.title('Comparison')
plt.show()
